# %%
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import decomposition, ensemble
import pandas as pd
import numpy as np
import numpy
import xgboost, textblob, string
from keras.preprocessing import text, sequence
from keras import layers, models, optimizers
# Out:
# Using TensorFlow backend.

# %%
data=pd.read_excel('D://AmazonPReparedDatabyAll//Balanced AMazon Categry.xlsx',encoding="utf8")
data=pd.DataFrame(data)
data


# # create a dataframe using texts and lables
# trainDF = pandas.DataFrame()
# trainDF['text'] = texts
# trainDF['label'] = labels
# Out:
#                Brand           price Rating  \
# 0            Coolpad            4999      1
# 1            Coolpad            6999      1
# 2            Coolpad            5499      1
# 3            Coolpad            9999      1
# 4             Google           83000      3
# 5             Google           83000      4
# 6             Google           71000      3
# 7             HOMTOM           10990      1
# 8             HOMTOM           10990      5
# 9             HOMTOM           10990      1
# 10            HOMTOM           10990      5
# 11             Honor           15999      1
# 12             Honor           15999      1
# 13             Honor           19999      1
# 14             Honor           19999      1
# 15    Amazon Renewed           25999      2
# 16             Honor           18999      1
# 17                LG           24000      1
# 18                LG           16990      3
# 19                LG           60000      1
# 20                LG           60000      1
# 21                LG  â‚¹Â 16,809.00      3
# 22                LG           29999      4
# 23    Amazon Renewed           10999      1
# 24          Micromax            4499      1
# 25              Moto           11999      1
# 26              Moto           11999      1
# 27              Moto           10999      1
# 28              Moto           10999      1
# 29    Amazon Renewed           15999      1
# ...              ...             ...    ...
# 2640             HTC          339.99      3
# 2641            Asus          235.16      4
# 2642             HTC              92      1
# 2643             HTC          149.99      5
# 2644             HTC          149.99      5
# 2645             HTC          149.99      2
# 2646             HTC          149.99      4
# 2647             HTC          149.99      5
# 2648             HTC          149.99      5
# 2649             HTC          149.99      4
# 2650             HTC          149.99      2
# 2651             HTC          149.99      4
# 2652             HTC          149.99      4
# 2653             HTC          149.99      2
# 2654             HTC          149.99      5
# 2655             HTC          149.99      5
# 2656             HTC          149.99      4
# 2657             HTC          149.99      4
# 2658             HTC          149.99      5
# 2659             HTC          149.99      5
# 2660             HTC          149.99      4
# 2661             HTC          149.99      5
# 2662             HTC          149.99      5
# 2663             HTC          149.99      5
# 2664             HTC          149.99      5
# 2665             HTC          149.99      5
# 2666             HTC          149.99      5
# 2667             HTC          149.99      5
# 2668             HTC          149.99      5
# 2669             HTC          159.95      1
#
#                                                   Title  Label  \
# 0                                         Worst product      1
# 1              touch of top part of display not working      1
# 2                            Touch not working properly      1
# 3                                    Don't buy these no      1
# 4          Google Support in India is not Satisfactory.      1
# 5                 Decent phone but bad hardware I guess      1
# 6           Google Pixel 3 phone hangs while operating.      1
# 7                                      very bad product      1
# 8     Homtom H3 is a good budget phone. Unfortunatel...      1
# 9                                      very bad product      1
# 10    Homtom H3 is a good budget phone. Unfortunatel...      1
# 11                                     Waste of money..      1
# 12                                     Waste of money..      1
# 13                                     Waste of money..      1
# 14                                     Waste of money..      1
# 15                         Purchase of Electronic Items      1
# 16                  SUCH DIS-HONOR AND WORST EXPERIENCE      1
# 17         Worst mobile and worst customer care/service      1
# 18                      Battery drainage, heating issue      1
# 19    For how lg treat customer , i am downrating fr...      1
# 20    For how lg treat customer , i am downrating fr...      1
# 21                      Battery drainage, heating issue      1
# 22                  Strange noise from leftside earbud.      1
# 23                                          REFURBISHED      1
# 24    wasted 5 days and then going to service center...      1
# 25    Delicate Phone, broken front and back with jus...      1
# 26              My Moto G6 is DEAD barely after 6months      1
# 27    Delicate Phone, broken front and back with jus...      1
# 28              My Moto G6 is DEAD barely after 6months      1
# 29                                      Amazon is worst      1
# ...                                                 ...    ...
# 2640                                                NaN      3
# 2641                                                NaN      3
# 2642                                                NaN      3
# 2643                                                NaN      3
# 2644                                                NaN      3
# 2645                                                NaN      3
# 2646                                                NaN      3
# 2647                                                NaN      3
# 2648                                                NaN      3
# 2649                                                NaN      3
# 2650                                                NaN      3
# 2651                                                NaN      3
# 2652                                                NaN      3
# 2653                                                NaN      3
# 2654                                                NaN      3
# 2655                                                NaN      3
# 2656                                                NaN      3
# 2657                                                NaN      3
# 2658                                                NaN      3
# 2659                                                NaN      3
# 2660                                                NaN      3
# 2661                                                NaN      3
# 2662                                                NaN      3
# 2663                                                NaN      3
# 2664                                                NaN      3
# 2665                                                NaN      3
# 2666                                                NaN      3
# 2667                                                NaN      3
# 2668                                                NaN      3
# 2669                                                NaN      3
#
#                                                  Review
# 0     Actually loss of money, worst service, adverti...
# 1     display top part touch not working service cen...
# 2     Actually touch is not working properly  i lost...
# 3                     Wast price no warrenty no service
# 4     Camera is awesome. Display is also fantastic. ...
# 5     I have been using this phone for about 40 - 50...
# 6     I have contacted the Google support team menti...
# 7     homtom product very bad pls don't purchagei pu...
# 8     Pros:Classy lookboth side glassmetal bezeldual...
# 9     homtom product very bad pls don't purchagei pu...
# 10    Pros:Classy lookboth side glassmetal bezeldual...
# 11    Worst purchase ever..Actually I bought this ph...
# 12    Worst purchase ever..Actually I bought this ph...
# 13    Worst purchase ever..Actually I bought this ph...
# 14    Worst purchase ever..Actually I bought this ph...
# 15    Hello Sir, The Mobile which we had received wa...
# 16    Disappointed. Within 2 months the volume outpu...
# 17    Worst phone I have ever bought. The mobile get...
# 18    I had a lot of problems with this set was cont...
# 19    EDIT : worst customer support .  they are not ...
# 20    EDIT : worst customer support .  they are not ...
# 21    I had a lot of problems with this set was cont...
# 22    Hello all,I ordered this product on 5th of Apr...
# 23    REFURBISHED MEANS SECOND HAND SET, CALL FOR RE...
# 24    NO to this product . This mobile battery drain...
# 25    fell from very short height but completely dam...
# 26    Moto G6 purchased on 13 June 2018 is dead by n...
# 27    fell from very short height but completely dam...
# 28    Moto G6 purchased on 13 June 2018 is dead by n...
# 29    Worst phone everPhone is dead without any reas...
# ...                                                 ...
# 2640  Gunmetal Grey stock as of 9-14-16 seems to be ...
# 2641           Item delivered on time, was as described
# 2642  The package arrived on time, but the original ...
# 2643  This was a gift for.my.nephew on his b'day&he ...
# 2644  I purchased this phone for my dad for Father's...
# 2645  The phone is locked. It does not accept SIM of...
# 2646  I ordered this phone from the seller above in ...
# 2647  BOUGHT TWO without hesitation after reading so...
# 2648  I picked this up for the wife because she was ...
# 2649  Let's face it, HTC is in trouble. The juggerna...
# 2650  I moved from IPhone to HTC One last year. I th...
# 2651  I am converting from an iPhone to this one...I...
# 2652  Did a lot of research on this cell before buyi...
# 2653        Not a big fan, I will stick with my IPhone.
# 2654  FAB .......... .............. ............. UU...
# 2655  HTC hit it out of the park with this one. I've...
# 2656  Great feel and function...impressed! Very part...
# 2657  It's like being married to a beautiful mute wo...
# 2658  I bought for my husband as a late birthday gif...
# 2659  do enjoy switched from S4 this uses less data ...
# 2660  My only knock is that integration into an all ...
# 2661  I have the One, my wife has the One Mini. We b...
# 2662    Like new! Works great! Fast shipping! Thanks!!!
# 2663  My spouse and I both chose this phone to repla...
# 2664  met my expectations fully and Amazon made the ...
# 2665  My wife and I recently decided to move away fr...
# 2666  I picked this up for the wife because she was ...
# 2667  picked up this phone on cyber Monday so I only...
# 2668  I bought one right after they came out and jus...
# 2669                             totalmente desecionado
#
# [2670 rows x 6 columns]

# %%
text=data.iloc[:,5]
label=data.iloc[:,4]

# %%
trainDF = pd.DataFrame()
trainDF['text'] = text
trainDF['label'] = label

# %%
trainDF
# Out:
#                                                    text  label
# 0     Actually loss of money, worst service, adverti...      1
# 1     display top part touch not working service cen...      1
# 2     Actually touch is not working properly  i lost...      1
# 3                     Wast price no warrenty no service      1
# 4     Camera is awesome. Display is also fantastic. ...      1
# 5     I have been using this phone for about 40 - 50...      1
# 6     I have contacted the Google support team menti...      1
# 7     homtom product very bad pls don't purchagei pu...      1
# 8     Pros:Classy lookboth side glassmetal bezeldual...      1
# 9     homtom product very bad pls don't purchagei pu...      1
# 10    Pros:Classy lookboth side glassmetal bezeldual...      1
# 11    Worst purchase ever..Actually I bought this ph...      1
# 12    Worst purchase ever..Actually I bought this ph...      1
# 13    Worst purchase ever..Actually I bought this ph...      1
# 14    Worst purchase ever..Actually I bought this ph...      1
# 15    Hello Sir, The Mobile which we had received wa...      1
# 16    Disappointed. Within 2 months the volume outpu...      1
# 17    Worst phone I have ever bought. The mobile get...      1
# 18    I had a lot of problems with this set was cont...      1
# 19    EDIT : worst customer support .  they are not ...      1
# 20    EDIT : worst customer support .  they are not ...      1
# 21    I had a lot of problems with this set was cont...      1
# 22    Hello all,I ordered this product on 5th of Apr...      1
# 23    REFURBISHED MEANS SECOND HAND SET, CALL FOR RE...      1
# 24    NO to this product . This mobile battery drain...      1
# 25    fell from very short height but completely dam...      1
# 26    Moto G6 purchased on 13 June 2018 is dead by n...      1
# 27    fell from very short height but completely dam...      1
# 28    Moto G6 purchased on 13 June 2018 is dead by n...      1
# 29    Worst phone everPhone is dead without any reas...      1
# ...                                                 ...    ...
# 2640  Gunmetal Grey stock as of 9-14-16 seems to be ...      3
# 2641           Item delivered on time, was as described      3
# 2642  The package arrived on time, but the original ...      3
# 2643  This was a gift for.my.nephew on his b'day&he ...      3
# 2644  I purchased this phone for my dad for Father's...      3
# 2645  The phone is locked. It does not accept SIM of...      3
# 2646  I ordered this phone from the seller above in ...      3
# 2647  BOUGHT TWO without hesitation after reading so...      3
# 2648  I picked this up for the wife because she was ...      3
# 2649  Let's face it, HTC is in trouble. The juggerna...      3
# 2650  I moved from IPhone to HTC One last year. I th...      3
# 2651  I am converting from an iPhone to this one...I...      3
# 2652  Did a lot of research on this cell before buyi...      3
# 2653        Not a big fan, I will stick with my IPhone.      3
# 2654  FAB .......... .............. ............. UU...      3
# 2655  HTC hit it out of the park with this one. I've...      3
# 2656  Great feel and function...impressed! Very part...      3
# 2657  It's like being married to a beautiful mute wo...      3
# 2658  I bought for my husband as a late birthday gif...      3
# 2659  do enjoy switched from S4 this uses less data ...      3
# 2660  My only knock is that integration into an all ...      3
# 2661  I have the One, my wife has the One Mini. We b...      3
# 2662    Like new! Works great! Fast shipping! Thanks!!!      3
# 2663  My spouse and I both chose this phone to repla...      3
# 2664  met my expectations fully and Amazon made the ...      3
# 2665  My wife and I recently decided to move away fr...      3
# 2666  I picked this up for the wife because she was ...      3
# 2667  picked up this phone on cyber Monday so I only...      3
# 2668  I bought one right after they came out and jus...      3
# 2669                             totalmente desecionado      3
#
# [2670 rows x 2 columns]

# %%
trainDF=trainDF.dropna()

# %%
nan_rows = trainDF[trainDF.isnull().T.any().T]
nan_rows
# Out:
# Empty DataFrame
# Columns: [text, label]
# Index: []

# %%
trainDF['text'] = trainDF.text.fillna(' ')
trainDF['label'] = trainDF.label.astype(int)

# %%
trainDF
# Out:
#                                                    text  label
# 0     Actually loss of money, worst service, adverti...      1
# 1     display top part touch not working service cen...      1
# 2     Actually touch is not working properly  i lost...      1
# 3                     Wast price no warrenty no service      1
# 4     Camera is awesome. Display is also fantastic. ...      1
# 5     I have been using this phone for about 40 - 50...      1
# 6     I have contacted the Google support team menti...      1
# 7     homtom product very bad pls don't purchagei pu...      1
# 8     Pros:Classy lookboth side glassmetal bezeldual...      1
# 9     homtom product very bad pls don't purchagei pu...      1
# 10    Pros:Classy lookboth side glassmetal bezeldual...      1
# 11    Worst purchase ever..Actually I bought this ph...      1
# 12    Worst purchase ever..Actually I bought this ph...      1
# 13    Worst purchase ever..Actually I bought this ph...      1
# 14    Worst purchase ever..Actually I bought this ph...      1
# 15    Hello Sir, The Mobile which we had received wa...      1
# 16    Disappointed. Within 2 months the volume outpu...      1
# 17    Worst phone I have ever bought. The mobile get...      1
# 18    I had a lot of problems with this set was cont...      1
# 19    EDIT : worst customer support .  they are not ...      1
# 20    EDIT : worst customer support .  they are not ...      1
# 21    I had a lot of problems with this set was cont...      1
# 22    Hello all,I ordered this product on 5th of Apr...      1
# 23    REFURBISHED MEANS SECOND HAND SET, CALL FOR RE...      1
# 24    NO to this product . This mobile battery drain...      1
# 25    fell from very short height but completely dam...      1
# 26    Moto G6 purchased on 13 June 2018 is dead by n...      1
# 27    fell from very short height but completely dam...      1
# 28    Moto G6 purchased on 13 June 2018 is dead by n...      1
# 29    Worst phone everPhone is dead without any reas...      1
# ...                                                 ...    ...
# 2640  Gunmetal Grey stock as of 9-14-16 seems to be ...      3
# 2641           Item delivered on time, was as described      3
# 2642  The package arrived on time, but the original ...      3
# 2643  This was a gift for.my.nephew on his b'day&he ...      3
# 2644  I purchased this phone for my dad for Father's...      3
# 2645  The phone is locked. It does not accept SIM of...      3
# 2646  I ordered this phone from the seller above in ...      3
# 2647  BOUGHT TWO without hesitation after reading so...      3
# 2648  I picked this up for the wife because she was ...      3
# 2649  Let's face it, HTC is in trouble. The juggerna...      3
# 2650  I moved from IPhone to HTC One last year. I th...      3
# 2651  I am converting from an iPhone to this one...I...      3
# 2652  Did a lot of research on this cell before buyi...      3
# 2653        Not a big fan, I will stick with my IPhone.      3
# 2654  FAB .......... .............. ............. UU...      3
# 2655  HTC hit it out of the park with this one. I've...      3
# 2656  Great feel and function...impressed! Very part...      3
# 2657  It's like being married to a beautiful mute wo...      3
# 2658  I bought for my husband as a late birthday gif...      3
# 2659  do enjoy switched from S4 this uses less data ...      3
# 2660  My only knock is that integration into an all ...      3
# 2661  I have the One, my wife has the One Mini. We b...      3
# 2662    Like new! Works great! Fast shipping! Thanks!!!      3
# 2663  My spouse and I both chose this phone to repla...      3
# 2664  met my expectations fully and Amazon made the ...      3
# 2665  My wife and I recently decided to move away fr...      3
# 2666  I picked this up for the wife because she was ...      3
# 2667  picked up this phone on cyber Monday so I only...      3
# 2668  I bought one right after they came out and jus...      3
# 2669                             totalmente desecionado      3
#
# [2670 rows x 2 columns]

# %%
train_x, valid_x, train_y, valid_y = model_selection.train_test_split(trainDF['text'], trainDF['label'])

# label encode the target variable 
encoder = preprocessing.LabelEncoder()
train_y = encoder.fit_transform(train_y)
valid_y = encoder.fit_transform(valid_y)

# %%
# create a count vectorizer object 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}')
count_vect.fit(trainDF['text'])

# transform the training and validation data using count vectorizer object
xtrain_count =  count_vect.transform(train_x)
xvalid_count =  count_vect.transform(valid_x)

# %%
# word level tf-idf
tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', max_features=5000)
tfidf_vect.fit(trainDF['text'])
xtrain_tfidf =  tfidf_vect.transform(train_x)
xvalid_tfidf =  tfidf_vect.transform(valid_x)

# ngram level tf-idf 
tfidf_vect_ngram = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(2,3), max_features=5000)
tfidf_vect_ngram.fit(trainDF['text'])
xtrain_tfidf_ngram =  tfidf_vect_ngram.transform(train_x)
xvalid_tfidf_ngram =  tfidf_vect_ngram.transform(valid_x)
print("Ngram:         ",xtrain_tfidf_ngram)

# characters level tf-idf
tfidf_vect_ngram_chars = TfidfVectorizer(analyzer='char', token_pattern=r'\w{1,}', ngram_range=(2,3), max_features=5000)
tfidf_vect_ngram_chars.fit(trainDF['text'])
xtrain_tfidf_ngram_chars =  tfidf_vect_ngram_chars.transform(train_x) 
xvalid_tfidf_ngram_chars =  tfidf_vect_ngram_chars.transform(valid_x) 
print("char:         ",xtrain_tfidf_ngram_chars)
# Out:
# Ngram:            (0, 4891)	0.2912251265567366
#   (0, 3729)	0.2672962230239982
#   (0, 3707)	0.5231729690368399
#   (0, 3705)	0.27760819727086133
#   (0, 2354)	0.24424899035370698
#   (0, 1218)	0.2738876323920237
#   (0, 1138)	0.28618878026562744
#   (0, 1132)	0.23063206106783168
#   (0, 941)	0.28618878026562744
#   (0, 18)	0.2912251265567366
#   (0, 14)	0.2376575809856815
#   (1, 4572)	0.2625744893545612
#   (1, 3609)	0.2645663676928317
#   (1, 3476)	0.3662460273207505
#   (1, 2258)	0.34912131588453515
#   (1, 2257)	0.30945725224676157
#   (1, 2251)	0.29699222086767213
#   (1, 1956)	0.3143492202106495
#   (1, 1777)	0.225791895339865
#   (1, 1022)	0.34912131588453515
#   (1, 968)	0.29699222086767213
#   (1, 614)	0.24734949759344568
#   (2, 4281)	0.2396955869568504
#   (2, 3314)	0.3862459139257528
#   (2, 3313)	0.3606462110544051
#   :	:
#   (2001, 812)	0.08402831195455848
#   (2001, 712)	0.08996745196768335
#   (2001, 711)	0.08610041382090965
#   (2001, 708)	0.0785780278027617
#   (2001, 655)	0.08996745196768335
#   (2001, 654)	0.07735518018628276
#   (2001, 550)	0.0872700255077088
#   (2001, 521)	0.08223337567413595
#   (2001, 493)	0.09155069797270643
#   (2001, 459)	0.0872700255077088
#   (2001, 418)	0.07133280737054239
#   (2001, 417)	0.04925789236521689
#   (2001, 382)	0.08402831195455848
#   (2001, 347)	0.08402831195455848
#   (2001, 344)	0.08141845619305783
#   (2001, 343)	0.06774877030129083
#   (2001, 339)	0.074710989655988
#   (2001, 293)	0.0872700255077088
#   (2001, 248)	0.0885511901556761
#   (2001, 190)	0.08502447536806601
#   (2001, 157)	0.13330169948538115
#   (2001, 155)	0.11686289600544066
#   (2001, 134)	0.08996745196768335
#   (2001, 90)	0.08310090600387932
#   (2001, 76)	0.08310090600387932
# char:            (0, 4960)	0.03834170559300107
#   (0, 4959)	0.037440262407350454
#   (0, 4935)	0.17863041807642663
#   (0, 4933)	0.037283564677006276
#   (0, 4932)	0.13522969493419065
#   (0, 4893)	0.07313320913737939
#   (0, 4892)	0.0594044468889297
#   (0, 4871)	0.035550492646273794
#   (0, 4868)	0.034802947590867835
#   (0, 4862)	0.03528503129758591
#   (0, 4844)	0.04688599986076948
#   (0, 4798)	0.0489682006571144
#   (0, 4797)	0.04505729597139353
#   (0, 4791)	0.10561649269600593
#   (0, 4788)	0.09658505766233808
#   (0, 4780)	0.024905583722342417
#   (0, 4775)	0.03620617672614989
#   (0, 4771)	0.045499568666020465
#   (0, 4766)	0.041224657473897135
#   (0, 4765)	0.027182628017362823
#   (0, 4679)	0.06792551633156775
#   (0, 4678)	0.036135403213844466
#   (0, 4671)	0.03755917693786265
#   (0, 4670)	0.03343735954274714
#   (0, 4662)	0.05617385814409045
#   :	:
#   (2001, 177)	0.01244221661710845
#   (2001, 175)	0.02596715511336293
#   (2001, 171)	0.02196277685927933
#   (2001, 168)	0.014127759172403517
#   (2001, 166)	0.03074537862631649
#   (2001, 164)	0.048633942739533
#   (2001, 162)	0.031434951873053826
#   (2001, 161)	0.01756789521759256
#   (2001, 157)	0.0328242157925169
#   (2001, 156)	0.024170672750832404
#   (2001, 155)	0.0684069332642999
#   (2001, 150)	0.013486739382477093
#   (2001, 148)	0.01628351525920841
#   (2001, 147)	0.06830548630258783
#   (2001, 145)	0.024824350458358794
#   (2001, 141)	0.016887289395616553
#   (2001, 140)	0.020329513884055343
#   (2001, 135)	0.04208093697454311
#   (2001, 134)	0.12193997995876106
#   (2001, 121)	0.03156411319816885
#   (2001, 118)	0.019739105466216957
#   (2001, 105)	0.02856744712318496
#   (2001, 103)	0.018325135301654263
#   (2001, 89)	0.029574441126247117
#   (2001, 80)	0.016345601326927896

# %%
trainDF['char_count'] = trainDF['text'].apply(len)
trainDF['word_count'] = trainDF['text'].apply(lambda x: len(x.split()))
trainDF['word_density'] = trainDF['char_count'] / (trainDF['word_count']+1)
trainDF['punctuation_count'] = trainDF['text'].apply(lambda x: len("".join(_ for _ in x if _ in string.punctuation))) 
trainDF['title_word_count'] = trainDF['text'].apply(lambda x: len([wrd for wrd in x.split() if wrd.istitle()]))
trainDF['upper_case_word_count'] = trainDF['text'].apply(lambda x: len([wrd for wrd in x.split() if wrd.isupper()]))

# %%
pos_family = {
    'noun' : ['NN','NNS','NNP','NNPS'],
    'pron' : ['PRP','PRP$','WP','WP$'],
    'verb' : ['VB','VBD','VBG','VBN','VBP','VBZ'],
    'adj' :  ['JJ','JJR','JJS'],
    'adv' : ['RB','RBR','RBS','WRB']
}

# function to check and get the part of speech tag count of a words in a given sentence
def check_pos_tag(x, flag):
    cnt = 0
    try:
        wiki = textblob.TextBlob(x)
        for tup in wiki.tags:
            ppo = list(tup)[1]
            if ppo in pos_family[flag]:
                cnt += 1
    except:
        pass
    return cnt

trainDF['noun_count'] = trainDF['text'].apply(lambda x: check_pos_tag(x, 'noun'))
trainDF['verb_count'] = trainDF['text'].apply(lambda x: check_pos_tag(x, 'verb'))
trainDF['adj_count'] = trainDF['text'].apply(lambda x: check_pos_tag(x, 'adj'))
trainDF['adv_count'] = trainDF['text'].apply(lambda x: check_pos_tag(x, 'adv'))
trainDF['pron_count'] = trainDF['text'].apply(lambda x: check_pos_tag(x, 'pron'))

# %%
trainDF
# Out:
#                                                    text  label  char_count  \
# 0     Actually loss of money, worst service, adverti...      1         122
# 1     display top part touch not working service cen...      1          75
# 2     Actually touch is not working properly  i lost...      1         189
# 3                     Wast price no warrenty no service      1          33
# 4     Camera is awesome. Display is also fantastic. ...      1         560
# 5     I have been using this phone for about 40 - 50...      1         834
# 6     I have contacted the Google support team menti...      1         432
# 7     homtom product very bad pls don't purchagei pu...      1         166
# 8     Pros:Classy lookboth side glassmetal bezeldual...      1         257
# 9     homtom product very bad pls don't purchagei pu...      1         166
# 10    Pros:Classy lookboth side glassmetal bezeldual...      1         257
# 11    Worst purchase ever..Actually I bought this ph...      1         514
# 12    Worst purchase ever..Actually I bought this ph...      1         514
# 13    Worst purchase ever..Actually I bought this ph...      1         514
# 14    Worst purchase ever..Actually I bought this ph...      1         514
# 15    Hello Sir, The Mobile which we had received wa...      1         607
# 16    Disappointed. Within 2 months the volume outpu...      1         573
# 17    Worst phone I have ever bought. The mobile get...      1         704
# 18    I had a lot of problems with this set was cont...      1         754
# 19    EDIT : worst customer support .  they are not ...      1        1701
# 20    EDIT : worst customer support .  they are not ...      1        1701
# 21    I had a lot of problems with this set was cont...      1         754
# 22    Hello all,I ordered this product on 5th of Apr...      1         750
# 23    REFURBISHED MEANS SECOND HAND SET, CALL FOR RE...      1          75
# 24    NO to this product . This mobile battery drain...      1         266
# 25    fell from very short height but completely dam...      1         321
# 26    Moto G6 purchased on 13 June 2018 is dead by n...      1         759
# 27    fell from very short height but completely dam...      1         321
# 28    Moto G6 purchased on 13 June 2018 is dead by n...      1         759
# 29    Worst phone everPhone is dead without any reas...      1         249
# ...                                                 ...    ...         ...
# 2640  Gunmetal Grey stock as of 9-14-16 seems to be ...      3         155
# 2641           Item delivered on time, was as described      3          40
# 2642  The package arrived on time, but the original ...      3         165
# 2643  This was a gift for.my.nephew on his b'day&he ...      3         111
# 2644  I purchased this phone for my dad for Father's...      3         407
# 2645  The phone is locked. It does not accept SIM of...      3         156
# 2646  I ordered this phone from the seller above in ...      3         630
# 2647  BOUGHT TWO without hesitation after reading so...      3        1470
# 2648  I picked this up for the wife because she was ...      3         320
# 2649  Let's face it, HTC is in trouble. The juggerna...      3        1942
# 2650  I moved from IPhone to HTC One last year. I th...      3         546
# 2651  I am converting from an iPhone to this one...I...      3        2791
# 2652  Did a lot of research on this cell before buyi...      3         162
# 2653        Not a big fan, I will stick with my IPhone.      3          43
# 2654  FAB .......... .............. ............. UU...      3         237
# 2655  HTC hit it out of the park with this one. I've...      3        2060
# 2656  Great feel and function...impressed! Very part...      3         205
# 2657  It's like being married to a beautiful mute wo...      3         135
# 2658  I bought for my husband as a late birthday gif...      3         623
# 2659  do enjoy switched from S4 this uses less data ...      3         123
# 2660  My only knock is that integration into an all ...      3         196
# 2661  I have the One, my wife has the One Mini. We b...      3          91
# 2662    Like new! Works great! Fast shipping! Thanks!!!      3          47
# 2663  My spouse and I both chose this phone to repla...      3        1255
# 2664  met my expectations fully and Amazon made the ...      3         137
# 2665  My wife and I recently decided to move away fr...      3         440
# 2666  I picked this up for the wife because she was ...      3         320
# 2667  picked up this phone on cyber Monday so I only...      3         267
# 2668  I bought one right after they came out and jus...      3         549
# 2669                             totalmente desecionado      3          22
#
#       word_count  word_density  punctuation_count  title_word_count  \
# 0             17      6.777778                  5                 2
# 1             12      5.769231                  0                 0
# 2             35      5.250000                  0                 2
# 3              6      4.714286                  0                 1
# 4             99      5.600000                 10                 8
# 5            145      5.712329                 23                11
# 6             77      5.538462                  6                 5
# 7             30      5.354839                  1                 0
# 8             28      8.862069                  4                 3
# 9             30      5.354839                  1                 0
# 10            28      8.862069                  4                 3
# 11            86      5.908046                 15                 5
# 12            86      5.908046                 15                 5
# 13            86      5.908046                 15                 5
# 14            86      5.908046                 15                 5
# 15           110      5.468468                 16                15
# 16            99      5.730000                 11                12
# 17           127      5.500000                 21                 8
# 18           139      5.385714                  7                 7
# 19           294      5.766102                 73                 2
# 20           294      5.766102                 73                 2
# 21           139      5.385714                  7                 7
# 22           145      5.136986                 16                10
# 23            11      6.250000                  3                 0
# 24            53      4.925926                  4                 1
# 25            59      5.350000                  7                 6
# 26           129      5.838462                 29                16
# 27            59      5.350000                  7                 6
# 28           129      5.838462                 29                16
# 29            45      5.413043                  5                 3
# ...          ...           ...                ...               ...
# 2640          29      5.166667                  7                 4
# 2641           7      5.000000                  1                 1
# 2642          32      5.000000                  6                 4
# 2643          20      5.285714                 10                 1
# 2644          74      5.426667                 10                 6
# 2645          30      5.032258                  4                 4
# 2646         115      5.431034                 19                 9
# 2647         263      5.568182                 52                17
# 2648          66      4.776119                  5                 8
# 2649         343      5.645349                 56                35
# 2650         102      5.300971                 16                11
# 2651         495      5.627016                 95                44
# 2652          33      4.764706                  3                 3
# 2653          10      3.909091                  2                 2
# 2654          25      9.115385                 83                 0
# 2655         385      5.336788                 69                43
# 2656          35      5.694444                  9                 7
# 2657          26      5.000000                  4                 1
# 2658         113      5.464912                 14                10
# 2659          21      5.590909                  0                 1
# 2660          31      6.125000                  9                 6
# 2661          20      4.333333                  4                 5
# 2662           7      5.875000                  6                 4
# 2663         225      5.553097                 23                19
# 2664          22      5.956522                  2                 1
# 2665          83      5.238095                 11                18
# 2666          66      4.776119                  5                 8
# 2667          49      5.340000                  8                 2
# 2668          97      5.602041                 12                 7
# 2669           2      7.333333                  0                 0
#
#       upper_case_word_count  noun_count  verb_count  adj_count  adv_count  \
# 0                         0           8           2          0          2
# 1                         0           6           2          2          2
# 2                         0           9           8          2          4
# 3                         0           3           0          1          1
# 4                         4          43          17          8          5
# 5                         3          43          37          9          4
# 6                         2          18          17          7          8
# 7                         0          17           4          6          2
# 8                         0          14           2          9          1
# 9                         0          17           4          6          2
# 10                        0          14           2          9          1
# 11                        3          22          21          8          4
# 12                        3          22          21          8          4
# 13                        3          22          21          8          4
# 14                        3          22          21          8          4
# 15                        3          23          30          7          9
# 16                        3          31          20          4          6
# 17                        2          30          28         10         14
# 18                        2          41          23          9         12
# 19                        3         103          48         37         16
# 20                        3         103          48         37         16
# 21                        2          41          23          9         12
# 22                        6          44          26         12         10
# 23                       11          11           1          0          0
# 24                        1          17           8          2          1
# 25                        3          17           9          6          4
# 26                        4          35          30          9         12
# 27                        3          17           9          6          4
# 28                        4          35          30          9         12
# 29                        1          14           7          3          0
# ...                     ...         ...         ...        ...        ...
# 2640                      1           7           7          3          3
# 2641                      0           3           2          0          0
# 2642                      2           7           8          2          2
# 2643                      0           5           4          1          2
# 2644                      2          15          15          6          7
# 2645                      1           8           7          1          2
# 2646                      2          25          22          9          9
# 2647                     43          88          39         24          9
# 2648                      4          10          14          2          6
# 2649                     17         101          59         43         17
# 2650                      7          27          22          6          8
# 2651                     13         112         100         44         44
# 2652                      1           9           5          3          2
# 2653                      1           2           1          1          1
# 2654                     21          22           1          0          0
# 2655                     16          96          72         34         29
# 2656                      3          12           4          3          5
# 2657                      1           6           6          4          0
# 2658                      4          26          19         10         14
# 2659                      1           5           6          3          4
# 2660                      1          12           3          2          1
# 2661                      2           5           4          1          0
# 2662                      0           3           1          2          0
# 2663                      9          63          32         23         15
# 2664                      0           7           3          2          2
# 2665                      6          23          16          4          7
# 2666                      4          10          14          2          6
# 2667                      1          14          10          5          4
# 2668                      2          22          21         11          9
# 2669                      0           2           0          0          0
#
#       pron_count
# 0              0
# 1              0
# 2              2
# 3              0
# 4              6
# 5              5
# 6              5
# 7              0
# 8              0
# 9              0
# 10             0
# 11            10
# 12            10
# 13            10
# 14            10
# 15            15
# 16             4
# 17             6
# 18             9
# 19             9
# 20             9
# 21             9
# 22            13
# 23             0
# 24             0
# 25             3
# 26             7
# 27             3
# 28             7
# 29             3
# ...          ...
# 2640           2
# 2641           0
# 2642           3
# 2643           3
# 2644           8
# 2645           2
# 2646          11
# 2647          13
# 2648           7
# 2649          18
# 2650          11
# 2651          42
# 2652           2
# 2653           2
# 2654           0
# 2655          40
# 2656           2
# 2657           3
# 2658          21
# 2659           0
# 2660           2
# 2661           4
# 2662           0
# 2663           8
# 2664           1
# 2665           7
# 2666           7
# 2667           1
# 2668          12
# 2669           0
#
# [2670 rows x 13 columns]

# %%
from sklearn import preprocessing
import sklearn.model_selection as ms
from sklearn import linear_model
import sklearn.metrics as sklm
import scipy.stats as ss
import math
import numpy.random as nr
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sklearn.metrics as sklm

from sklearn.metrics import classification_report
import seaborn as sn

# %%
def print_metrics(labels, scores):
    metrics = sklm.precision_recall_fscore_support(labels, scores)
    conf = sklm.confusion_matrix(labels, scores)
    print('                 Confusion matrix')
    print('                   Score Prod&serv  Score Price  Score Delivery&oth')
    print('Actual Prod&Serv    %6d' % conf[0,0] + '           %5d' % conf[0,1] + '           %5d' % conf[0,2])
    print('Actual price        %6d' % conf[1,0] + '           %5d' % conf[1,1] + '           %5d' % conf[1,2])
    print('Actual Delivery&Oth %6d' % conf[2,0] + '           %5d' % conf[2,1] + '           %5d' % conf[2,2])
    print('---------------------REPORT-------------------------')
    print(classification_report(labels,scores))
#     dfconf=pd.DataFrame(conf)
#     index = ['Prod&Serv','price','Delivery&Oth']  
#     columns = ['Prod&Serv','price','Delivery&Oth']  
#     cm_df = pd.DataFrame(conf,columns,index)
# #     sn.set(font_scale=1.4)#for label size
#     sn.heatmap(cm_df, annot=True,annot_kws={"size": 16})# font size

# %%
def train_model(classifier, feature_vector_train, label, feature_vector_valid, is_neural_net=False):
    # fit the training dataset on the classifier
    classifier.fit(feature_vector_train, label)
    
    # predict the labels on validation dataset
    predictions = classifier.predict(feature_vector_valid)
    print_metrics(valid_y, predictions)

    
    
    if is_neural_net:
        predictions = predictions.argmax(axis=-1)
           

     
    return metrics.accuracy_score(predictions, valid_y)

# %%
# Naive Bayes on Count Vectors
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_count, train_y, xvalid_count)
print ("NB, Count Vectors: ", accuracy)

# Naive Bayes on Word Level TF IDF Vectors
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_tfidf, train_y, xvalid_tfidf)
print ("NB, WordLevel TF-IDF: ", accuracy)

# Naive Bayes on Ngram Level TF IDF Vectors
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_tfidf_ngram, train_y, xvalid_tfidf_ngram)
print ("NB, N-Gram Vectors: ", accuracy)

# Naive Bayes on Character Level TF IDF Vectors
accuracy = train_model(naive_bayes.MultinomialNB(), xtrain_tfidf_ngram_chars, train_y, xvalid_tfidf_ngram_chars)
print ("NB, CharLevel Vectors: ", accuracy)
# Out:
#                  Confusion matrix
#                    Score Prod&serv  Score Price  Score Delivery&oth
# Actual Prod&Serv       156              47              15
# Actual price            22             200              17
# Actual Delivery&Oth     34              30             147
# ---------------------REPORT-------------------------
#               precision    recall  f1-score   support
#
#            0       0.74      0.72      0.73       218
#            1       0.72      0.84      0.78       239
#            2       0.82      0.70      0.75       211
#
#    micro avg       0.75      0.75      0.75       668
#    macro avg       0.76      0.75      0.75       668
# weighted avg       0.76      0.75      0.75       668
#
# NB, Count Vectors:  0.7529940119760479
#                  Confusion matrix
#                    Score Prod&serv  Score Price  Score Delivery&oth
# Actual Prod&Serv       160              41              17
# Actual price            20             200              19
# Actual Delivery&Oth     32              18             161
# ---------------------REPORT-------------------------
#               precision    recall  f1-score   support
#
#            0       0.75      0.73      0.74       218
#            1       0.77      0.84      0.80       239
#            2       0.82      0.76      0.79       211
#
#    micro avg       0.78      0.78      0.78       668
#    macro avg       0.78      0.78      0.78       668
# weighted avg       0.78      0.78      0.78       668
#
# NB, WordLevel TF-IDF:  0.7799401197604791
#                  Confusion matrix
#                    Score Prod&serv  Score Price  Score Delivery&oth
# Actual Prod&Serv       141              45              32
# Actual price            17             193              29
# Actual Delivery&Oth     24              39             148
# ---------------------REPORT-------------------------
#               precision    recall  f1-score   support
#
#            0       0.77      0.65      0.71       218
#            1       0.70      0.81      0.75       239
#            2       0.71      0.70      0.70       211
#
#    micro avg       0.72      0.72      0.72       668
#    macro avg       0.73      0.72      0.72       668
# weighted avg       0.73      0.72      0.72       668
#
# NB, N-Gram Vectors:  0.7215568862275449
#                  Confusion matrix
#                    Score Prod&serv  Score Price  Score Delivery&oth
# Actual Prod&Serv       156              36              26
# Actual price            30             184              25
# Actual Delivery&Oth     27              19             165
# ---------------------REPORT-------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.72       218
#            1       0.77      0.77      0.77       239
#            2       0.76      0.78      0.77       211
#
#    micro avg       0.76      0.76      0.76       668
#    macro avg       0.76      0.76      0.76       668
# weighted avg       0.76      0.76      0.76       668
#
# NB, CharLevel Vectors:  0.7559880239520959

# %%
# Linear Classifier on Count Vectors
accuracy = train_model(linear_model.LogisticRegression(), xtrain_count, train_y, xvalid_count)
print ("LR, Count Vectors: ", accuracy)

# Linear Classifier on Word Level TF IDF Vectors
accuracy = train_model(linear_model.LogisticRegression(), xtrain_tfidf, train_y, xvalid_tfidf)
print ("LR, WordLevel TF-IDF: ", accuracy)

# Linear Classifier on Ngram Level TF IDF Vectors
accuracy = train_model(linear_model.LogisticRegression(), xtrain_tfidf_ngram, train_y, xvalid_tfidf_ngram)
print ("LR, N-Gram Vectors: ", accuracy)

# Linear Classifier on Character Level TF IDF Vectors
accuracy = train_model(linear_model.LogisticRegression(), xtrain_tfidf_ngram_chars, train_y, xvalid_tfidf_ngram_chars)
print ("LR, CharLevel Vectors: ", accuracy)
# Out:
# C:\Users\Vicky\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Vicky\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
#                  Confusion matrix
#                    Score Prod&serv  Score Price  Score Delivery&oth
# Actual Prod&Serv       175              18              25
# Actual price            20             200              19
# Actual Delivery&Oth     25              10             176
# ---------------------REPORT-------------------------
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80       218
#            1       0.88      0.84      0.86       239
#            2       0.80      0.83      0.82       211
#
#    micro avg       0.82      0.82      0.82       668
#    macro avg       0.82      0.82      0.82       668
# weighted avg       0.83      0.82      0.83       668
#
# LR, Count Vectors:  0.8248502994011976
#                  Confusion matrix
#                    Score Prod&serv  Score Price  Score Delivery&oth
# Actual Prod&Serv       173              17              28
# Actual price            21             194              24
# Actual Delivery&Oth     25               6             180
# ---------------------REPORT-------------------------
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79       218
#            1       0.89      0.81      0.85       239
#            2       0.78      0.85      0.81       211
#
#    micro avg       0.82      0.82      0.82       668
#    macro avg       0.82      0.82      0.82       668
# weighted avg       0.82      0.82      0.82       668
#
# LR, WordLevel TF-IDF:  0.8188622754491018
#                  Confusion matrix
#                    Score Prod&serv  Score Price  Score Delivery&oth
# Actual Prod&Serv       151              23              44
# Actual price            28             181              30
# Actual Delivery&Oth     31              12             168
# ---------------------REPORT-------------------------
#               precision    recall  f1-score   support
#
#            0       0.72      0.69      0.71       218
#            1       0.84      0.76      0.80       239
#            2       0.69      0.80      0.74       211
#
#    micro avg       0.75      0.75      0.75       668
#    macro avg       0.75      0.75      0.75       668
# weighted avg       0.75      0.75      0.75       668
#
# LR, N-Gram Vectors:  0.7485029940119761
#                  Confusion matrix
#                    Score Prod&serv  Score Price  Score Delivery&oth
# Actual Prod&Serv       163              22              33
# Actual price            25             191              23
# Actual Delivery&Oth     18              12             181
# ---------------------REPORT-------------------------
#               precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77       218
#            1       0.85      0.80      0.82       239
#            2       0.76      0.86      0.81       211
#
#    micro avg       0.80      0.80      0.80       668
#    macro avg       0.80      0.80      0.80       668
# weighted avg       0.80      0.80      0.80       668
#
# LR, CharLevel Vectors:  0.8008982035928144

# %%
# SVM on Ngram Level TF IDF Vectors
accuracy = train_model(svm.SVC(), xtrain_tfidf_ngram, train_y, xvalid_tfidf_ngram)
print ("SVM, N-Gram Vectors: ", accuracy)
# Out:
# C:\Users\Vicky\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
#                  Confusion matrix
#                    Score Prod&serv  Score Price  Score Delivery&oth
# Actual Prod&Serv         0             218               0
# Actual price             0             239               0
# Actual Delivery&Oth      0             211               0
# ---------------------REPORT-------------------------
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       218
#            1       0.36      1.00      0.53       239
#            2       0.00      0.00      0.00       211
#
#    micro avg       0.36      0.36      0.36       668
#    macro avg       0.12      0.33      0.18       668
# weighted avg       0.13      0.36      0.19       668
#
# SVM, N-Gram Vectors:  0.35778443113772457
# C:\Users\Vicky\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Vicky\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Vicky\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Vicky\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# RF on Count Vectors
accuracy = train_model(ensemble.RandomForestClassifier(), xtrain_count, train_y, xvalid_count)
print ("RF, Count Vectors: ", accuracy)

# RF on Word Level TF IDF Vectors
accuracy = train_model(ensemble.RandomForestClassifier(), xtrain_tfidf, train_y, xvalid_tfidf)
print ("RF, WordLevel TF-IDF: ", accuracy)
# Out:
# C:\Users\Vicky\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
#                  Confusion matrix
#                    Score Prod&serv  Score Price  Score Delivery&oth
# Actual Prod&Serv       162              32              24
# Actual price            20             203              16
# Actual Delivery&Oth     27              20             164
# ---------------------REPORT-------------------------
#               precision    recall  f1-score   support
#
#            0       0.78      0.74      0.76       218
#            1       0.80      0.85      0.82       239
#            2       0.80      0.78      0.79       211
#
#    micro avg       0.79      0.79      0.79       668
#    macro avg       0.79      0.79      0.79       668
# weighted avg       0.79      0.79      0.79       668
#
# RF, Count Vectors:  0.7919161676646707
# C:\Users\Vicky\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
#                  Confusion matrix
#                    Score Prod&serv  Score Price  Score Delivery&oth
# Actual Prod&Serv       157              26              35
# Actual price            30             187              22
# Actual Delivery&Oth     31              12             168
# ---------------------REPORT-------------------------
#               precision    recall  f1-score   support
#
#            0       0.72      0.72      0.72       218
#            1       0.83      0.78      0.81       239
#            2       0.75      0.80      0.77       211
#
#    micro avg       0.77      0.77      0.77       668
#    macro avg       0.77      0.77      0.77       668
# weighted avg       0.77      0.77      0.77       668
#
# RF, WordLevel TF-IDF:  0.7664670658682635

# %%
valid_x.shape
# Out:
# (668,)
